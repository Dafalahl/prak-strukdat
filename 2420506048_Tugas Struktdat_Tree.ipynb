# %%
# Struktur Tree berdasarkan identitas saya

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def inorder_traversal(node):
    if node:
        inorder_traversal(node.left)
        print(node.data, end=" ")
        inorder_traversal(node.right)

# Data
nama = "Muhammad Dafa"
npm = "2420506048"
tanggal_lahir = "01-01-2005"

# Hitung node-node
root_val = len(nama.replace(" ", ""))
vokal_count = sum(1 for c in nama.lower() if c in "aiueo")
npm_2digit = int(npm[-2:])
tanggal = int(tanggal_lahir[:2])
bulan = int(tanggal_lahir[3:5])

# Bangun tree manual
root = Node(root_val)
root.left = Node(vokal_count)
root.right = Node(npm_2digit)

root.left.left = Node(tanggal)
root.right.right = Node(bulan)

# Tampilkan tree (inorder)
print("Struktur Tree berdasarkan identitas saya:")
inorder_traversal(root)
# Out:
# Struktur Tree berdasarkan identitas saya:
# 1 5 12 48 1

# %%
# Program Binary Search Tree (BST)
# Berdasarkan identitas saya

class Node:
    def __init__(self, key):
        self.key = key
        self.left = None
        self.right = None

def insert(root, key):
    if root is None:
        return Node(key)
    if key < root.key:
        root.left = insert(root.left, key)
    else:
        root.right = insert(root.right, key)
    return root

def inorder(node):
    if node:
        inorder(node.left)
        print(node.key, end=" ")
        inorder(node.right)

def preorder(node):
    if node:
        print(node.key, end=" ")
        preorder(node.left)
        preorder(node.right)

def postorder(node):
    if node:
        postorder(node.left)
        postorder(node.right)
        print(node.key, end=" ")

def search(root, target):
    if root is None:
        return False
    if root.key == target:
        return True
    elif target < root.key:
        return search(root.left, target)
    else:
        return search(root.right, target)

# Data dari identitas
data = [48, 1, 1, 77, 117, 99, 7]
root = None
for num in data:
    root = insert(root, num)

# Tampilkan traversal
print("Inorder Traversal:")
inorder(root)
print("\nPreorder Traversal:")
preorder(root)
print("\nPostorder Traversal:")
postorder(root)

# Pencarian
cari_angka = 48  # dua digit terakhir NPM
angka_tidak_ada = 123  # angka bebas yg tidak ada di tree

print(f"\n\nCari angka {cari_angka}: {'Ditemukan' if search(root, cari_angka) else 'Tidak ditemukan'}")
print(f"Cari angka {angka_tidak_ada}: {'Ditemukan' if search(root, angka_tidak_ada) else 'Tidak ditemukan'}")
# Out:
# Inorder Traversal:
# 1 1 7 48 77 99 117
# Preorder Traversal:
# 48 1 1 7 77 117 99
# Postorder Traversal:
# 7 1 1 99 117 77 48
#
# Cari angka 48: Ditemukan
# Cari angka 123: Tidak ditemukan
