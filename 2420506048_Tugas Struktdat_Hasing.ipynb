# %%
class LinearProbingHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [None] * size

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)

        # Linear probing untuk mencari slot kosong
        while self.table[index] is not None and self.table[index][0] != key:
            index = (index + 1) % self.size

        self.table[index] = (key, value)

    def print_table(self):
        print("Isi tabel hash:")
        for i, item in enumerate(self.table):
            print(f"Slot {i}: {item}")

# a. Buat objek dengan ukuran 5
ht = LinearProbingHashTable(5)

# b. Masukkan data
ht.insert("A", 10)
ht.insert("B", 20)
ht.insert("C", 30)
ht.insert("D", 40)
ht.insert("E", 50)

# c. Cetak isi tabel
ht.print_table()
# Out:
# Isi tabel hash:
# Slot 0: ('A', 10)
# Slot 1: ('B', 20)
# Slot 2: ('D', 40)
# Slot 3: ('E', 50)
# Slot 4: ('C', 30)

# %%
class ChainingHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [[] for _ in range(size)]

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        for i, (k, v) in enumerate(self.table[index]):
            if k == key:
                self.table[index][i] = (key, value)
                return
        self.table[index].append((key, value))

    def print_table(self):
        print("Isi tabel hash (chaining):")
        for i, chain in enumerate(self.table):
            print(f"Slot {i}: {chain}")

# a. Buat objek dengan ukuran 3
ht = ChainingHashTable(3)

# b. Masukkan data
ht.insert("apel", 100)
ht.insert("melon", 200)
ht.insert("lemon", 300)
ht.insert("pisang", 400)

# c. Cetak isi tabel
ht.print_table()
# Out:
# Isi tabel hash (chaining):
# Slot 0: [('lemon', 300)]
# Slot 1: []
# Slot 2: [('apel', 100), ('melon', 200), ('pisang', 400)]
